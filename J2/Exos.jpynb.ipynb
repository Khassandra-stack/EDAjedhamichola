# %% [markdown]
# # Scatter_plot_viz

# %% [markdown]
#     1.Import usefull librairies (pandas, seaborn, matplotlib, numpy)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
#     2.Give the list of variables present in this dataset as well as their nature
#     (are they qualitative, quantitative, discrete etc...) and their type (float, int, str etc...).

# %%
df = pd.read_csv('Exos/house_pricing.csv')
pd.set_option('display.max_columns', None)
df.head(11)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.describe(include='all').transpose()
# Out:
#                 count unique      top  freq          mean           std  \
# Id             1460.0    NaN      NaN   NaN         730.5    421.610009
# MSSubClass     1460.0    NaN      NaN   NaN      56.89726     42.300571
# MSZoning         1460      5       RL  1151           NaN           NaN
# LotFrontage    1201.0    NaN      NaN   NaN     70.049958     24.284752
# LotArea        1460.0    NaN      NaN   NaN  10516.828082   9981.264932
# Street           1460      2     Pave  1454           NaN           NaN
# Alley              91      2     Grvl    50           NaN           NaN
# LotShape         1460      4      Reg   925           NaN           NaN
# LandContour      1460      4      Lvl  1311           NaN           NaN
# Utilities        1460      2   AllPub  1459           NaN           NaN
# LotConfig        1460      5   Inside  1052           NaN           NaN
# LandSlope        1460      3      Gtl  1382           NaN           NaN
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
#     3.When creating a scatterplot, look at how the LotArea column behaves in relation to the SalePrices column.

# %%
sns.scatterplot(data=df, x='SalePrice', y="LotArea")
# plus on filtre plus bas, plus on verra d'autre précisions relatifs à la linéarité
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %% [markdown]
#     4.Refine your visualization by keeping only those houses that have a LotArea of less than 20,000 square feet and a price of less than $500,000.

# %%
# creer df1 en appliquand sur les colonnes les filtres concernées des 2 colonne et afficher ensuite le df1
#apprendre à bien expliqué les visualisation

# %% [markdown]
# # Heatmaps

# %% [markdown]
#     1.Import usual librairies

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
#     2.Import the dataset named house_pricing.csv.

# %%
df = pd.read_csv('Exos/house_pricingHtmap.csv')
df.head(8)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %% [markdown]
#     4.Cut out the dataset to keep only the last 15 columns.

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df1 = df.loc[:,['WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice']]
df1.head()


# pour decouper, kev a 
#cols = df.columns(-15)
#df = df[cols]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\CHAFFA~1\AppData\Local\Temp/ipykernel_19388/667941766.py in <module>
# ----> 1 df1 = df.loc[:,['WoodDeckSF', 'OpenPorchSF',
#       2        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#       3        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#       4        'SaleCondition', 'SalePrice']]
#       5 df1.head()
#
# c:\Users\CHAFFA Michèle\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ...

# %%
df1.describe(include='all').transpose()
# Out:
#                 count unique     top  freq          mean           std  \
# WoodDeckSF     1460.0    NaN     NaN   NaN     94.244521    125.338794
# OpenPorchSF    1460.0    NaN     NaN   NaN     46.660274     66.256028
# EnclosedPorch  1460.0    NaN     NaN   NaN      21.95411     61.119149
# 3SsnPorch      1460.0    NaN     NaN   NaN      3.409589     29.317331
# ScreenPorch    1460.0    NaN     NaN   NaN     15.060959     55.757415
# PoolArea       1460.0    NaN     NaN   NaN      2.758904     40.177307
# PoolQC              7      3      Gd     3           NaN           NaN
# Fence             281      4   MnPrv   157           NaN           NaN
# MiscFeature        54      4    Shed    49           NaN           NaN
# MiscVal        1460.0    NaN     NaN   NaN     43.489041    496.123024
# MoSold         1460.0    NaN     NaN   NaN      6.321918      2.703626
# YrSold         1460.0    NaN     NaN   NaN   2007.815753      1.328095
# ...

# %% [markdown]
#     3.Create a correlation matrix with all dataset's variables

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   WoodDeckSF     1460 non-null   int64
#  1   OpenPorchSF    1460 non-null   int64
#  2   EnclosedPorch  1460 non-null   int64
#  3   3SsnPorch      1460 non-null   int64
#  4   ScreenPorch    1460 non-null   int64
#  5   PoolArea       1460 non-null   int64
#  6   PoolQC         7 non-null      object
#  7   Fence          281 non-null    object
#  8   MiscFeature    54 non-null     object
#  9   MiscVal        1460 non-null   int64
#  10  MoSold         1460 non-null   int64
#  11  YrSold         1460 non-null   int64
#  12  SaleType       1460 non-null   object
#  13  SaleCondition  1460 non-null   object
#  14  SalePrice      1460 non-null   int64
# dtypes: int64(10), object(5)
# memory usage: 171.2+ KB

# %%
#pour avoir que les colonnes "numériques" pour la matrice de corrélation ___ Option 1 collègues
corr = df.corr(numeric_only=True)

# %%
#une methode pour selectionner les colonnes numériques uniquement : ___ Option 2 collègues
df1 = df1.select_dtypes(include='int64')

# %%
# Create correlation matrix
df2 = df1.loc[:,['WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal','MoSold','YrSold','SalePrice']]
df2
# Out:
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# 5             40           30              0        320            0
# 6            255           57              0          0            0
# 7            235          204            228          0            0
# 8             90            0            205          0            0
# 9              0            4              0          0            0
# 10             0            0              0          0            0
# 11           147           21              0          0            0
# 12           140            0              0          0          176
# ...

# %%
corr_matrix = df2.corr()
corr_matrix
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %%
# build heat map of correlation matrix
sns.heatmap(corr_matrix, annot=True, linewidth=.5)

#Chercher à agrandir
# Out:
# <AxesSubplot:>

# %% [markdown]
#     5.What is the top 3 features we should keep to predict SalePrice ?

# %%
# Voir ce que Kev a fait dans le chat avec Geraldine

# %% [markdown]
# # Linear relationships

# %% [markdown]
#     1.Import usual librairies

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
#     2.Import dataset

# %%
df = pd.read_csv('Exos/IBM_HR_ATTRITION.csv')
df.head(8)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df['Attrition'].value_counts()
# Remplacer le no et le yes par 1 et 0
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df.describe(include='all').transpose()
# Out:
#                            count unique                     top  freq  \
# Age                       1470.0    NaN                     NaN   NaN
# Attrition                   1470      2                      No  1233
# BusinessTravel              1470      3           Travel_Rarely  1043
# DailyRate                 1470.0    NaN                     NaN   NaN
# Department                  1470      3  Research & Development   961
# DistanceFromHome          1470.0    NaN                     NaN   NaN
# Education                 1470.0    NaN                     NaN   NaN
# EducationField              1470      6           Life Sciences   606
# EmployeeCount             1470.0    NaN                     NaN   NaN
# EmployeeNumber            1470.0    NaN                     NaN   NaN
# EnvironmentSatisfaction   1470.0    NaN                     NaN   NaN
# Gender                      1470      2                    Male   882
# ...

# %% [markdown]
#     3.We would like to know the probability of leaving the business in relation to the distance from home.
#         Use lmplot() to view this. What can you conclude?

# %%
sns.lmplot(data=df, x="DistanceFromHome", y="Attrition")
# prendre les variables explicatives pour le x
# c'est la variable à expliquer , c'est l'attrition (relation binaire soit je quitte l'entreprise ou je ne quitte pas)
# on est dans le cas d'une classification qui nous permet d'avoir une reponse en 2 temps. 
# Donc bien lire et faire le ML pour pouvoir avoir la probabilté

# %%
sns.lmplot(x="DistanceFromHome", y="Attrition", data= dataset, logistic = True, scatter_kws={"alpha":.05})
