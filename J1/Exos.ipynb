# %% [markdown]
# # <span style="color:red">**Explore_a_db**</span>

# %% [markdown]
#     1.Import libraries

# %%
import pandas as pd

# %% [markdown]
#     2.Import dataset

# %%
df = pd.read_csv('src/chipotle.csv')
df
# Out:
#       Unnamed: 0  order_id  quantity                              item_name  \
# 0              0         1         1           Chips and Fresh Tomato Salsa
# 1              1         1         1                                   Izze
# 2              2         1         1                       Nantucket Nectar
# 3              3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4              4         2         2                           Chicken Bowl
# ...          ...       ...       ...                                    ...
# 4617        4617      1833         1                          Steak Burrito
# 4618        4618      1833         1                          Steak Burrito
# 4619        4619      1834         1                     Chicken Salad Bowl
# 4620        4620      1834         1                     Chicken Salad Bowl
# 4621        4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 6 columns]

# %% [markdown]
#     3.Look at the 10 first rows in the dataset

# %%
df.head(10)
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
# 5           5         3         1                           Chicken Bowl
# 6           6         3         1                          Side of Chips
# 7           7         4         1                          Steak Burrito
# 8           8         4         1                       Steak Soft Tacos
# 9           9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
#     4.What is the shape of the dataset ?

# %%
df.shape
# Out:
# (4622, 6)

# %% [markdown]
#     5.Display all the columns of our dataset

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
#     6.What is the most ordered item?
#         Indication: we will use GROUP BY & Sort_values()

# %%
df.groupby(['item_name']).sum().sort_values(by='quantity',ascending=False)
# Out:
#                                        Unnamed: 0  order_id  quantity
# item_name
# Chicken Bowl                              1779909    713926       761
# Chicken Burrito                           1238217    497303       591
# Chips and Guacamole                       1121773    449959       506
# Steak Burrito                              817795    328437       386
# Canned Soft Drink                          759990    304753       351
# Chips                                      518704    208004       230
# Steak Bowl                                 482721    193752       221
# Bottled Water                              439354    175944       211
# Chips and Fresh Tomato Salsa               250144    100419       130
# Canned Soda                                189915     76396       126
# Chicken Salad Bowl                         292292    117104       123
# Chicken Soft Tacos                         244891     98395       120
# Side of Chips                              211009     84769       110
# Veggie Burrito                             201321     80962        97
# Barbacoa Burrito                           185979     74718        91
# Veggie Bowl                                180046     72270        87
# Carnitas Bowl                              156599     62742        71
# Barbacoa Bowl                              134264     53972        66
# Carnitas Burrito                           128611     51652        60
# Steak Soft Tacos                           125012     50177        56
# 6 Pack Soft Drink                          130318     52322        55
# Chips and Tomatillo Red Chili Salsa        113585     45556        50
# Chicken Crispy Tacos                       118393     47382        50
# Chips and Tomatillo Green Chili Salsa      102435     41170        45
# Carnitas Soft Tacos                         93766     37673        40
# Steak Crispy Tacos                          89408     35818        36
# Chips and Tomatillo-Green Chili Salsa       54211     21826        33
# Steak Salad Bowl                            73953     29590        31
# Nantucket Nectar                            54403     21814        29
# Chips and Tomatillo-Red Chili Salsa         45650     18344        25
# Barbacoa Soft Tacos                         46454     18725        25
# Chips and Roasted Chili Corn Salsa          37152     14999        23
# Izze                                        26280     10587        20
# Veggie Salad Bowl                           43124     17303        18
# Chips and Roasted Chili-Corn Salsa          43554     17462        18
# Barbacoa Crispy Tacos                       13825      5613        12
# Barbacoa Salad Bowl                         24161      9708        10
# Chicken Salad                               26125     10465         9
# Carnitas Crispy Tacos                       14567      5868         8
# Veggie Soft Tacos                           13737      5520         8
# Burrito                                      3734      1550         6
# Veggie Salad                                18164      7265         6
# Carnitas Salad Bowl                         16710      6693         6
# Bowl                                         1118       472         4
# Steak Salad                                  5811      2362         4
# Salad                                        2829      1150         2
# Crispy Tacos                                 1041       434         2
# Chips and Mild Fresh Tomato Salsa             674       279         1
# Carnitas Salad                               3750      1500         1
# Veggie Crispy Tacos                          1653       668         1

# %% [markdown]
#     7.How many items were ordered from Chipotle in total?

# %%
df['quantity'].sum()
# Out:
# 4972

# %% [markdown]
#     8.How much revenue has Chipotle made?

# %% [markdown]
# A. Convert item_price to a decimal number. 1. Look at dataset [ item_price ], what do you see? 2. Let's find a way to get that $ out of our way. We can do that by using str 3. Let's now convert the series to float instead of string

# %%
df.item_price
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df['item_price'] = df.item_price.str.replace('$','')
df['item_price']
# Out:
# C:\Users\CHAFFA~1\AppData\Local\Temp/ipykernel_4608/2820094968.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['item_price'] = df.item_price.str.replace('$','')
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df["item_price"]= df.item_price.astype(float)
df.dtypes
# Out:
# Unnamed: 0              int64
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %% [markdown]
# B. Multiply the quantity sold by the price of the item.

# %%
df['revenue']=df['item_price']*df['quantity']
df.tail()
# Out:
#       Unnamed: 0  order_id  quantity           item_name  \
# 4617        4617      1833         1       Steak Burrito
# 4618        4618      1833         1       Steak Burrito
# 4619        4619      1834         1  Chicken Salad Bowl
# 4620        4620      1834         1  Chicken Salad Bowl
# 4621        4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price  revenue
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75    11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75    11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25    11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75     8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75     8.75

# %% [markdown]
# C. Add it all up, how much do you find?
#
# D. Round to two decimal places. #We can use the Series.round() function.

# %%
total_amount = round((df['revenue'].sum()),2)
total_amount
#
# Out:
# 39237.02

# %% [markdown]
#     9.What is the average revenue per order?

# %%
df1=df.groupby(['order_id']).sum()
df1.mean()
# Out:
# Unnamed: 0    5822.863141
# quantity         2.711014
# item_price      18.811429
# revenue         21.394231
# dtype: float64

# %% [markdown]
# # <span style="color:red">**House market**</span>

# %% [markdown]
#     1.Import libraries

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
#     2.Download the four files “superficie.csv” / “nombre_de_sdb.csv” / “nombre_de_chambres.csv” / "house_price.csv"

# %%
df1=pd.read_csv('house_market/superficie.csv',header=None)
df1.head(5)
# Out:
#    0      1
# 0  0  28844
# 1  1  27667
# 2  2  14742
# 3  3  28089
# 4  4  11713

# %%
df2=pd.read_csv('house_market/nombre_de_sdb.csv',header=None)
df2.head(5), df2.shape
# Out:
# (   0  1
#  0  0  2
#  1  1  1
#  2  2  1
#  3  3  3
#  4  4  1,
#  (100, 2))

# %%
df3=pd.read_csv('house_market/nombre_de_chambres.csv',header=None)
df3.head(5) , df3.shape
# Out:
# (   0  1
#  0  0  1
#  1  1  4
#  2  2  1
#  3  3  4
#  4  4  2,
#  (100, 2))

# %%
df4=pd.read_csv('house_market/house_price.csv', index_col=0)
df4.head(5)
# Out:
#    id  house_price
# 0  14    1918154.0
# 1  30     739142.0
# 2  70    1621938.0
# 3  77    1319862.0
# 4  50     146250.0

# %% [markdown]
#     3.Give a column name to the three datasets that don't have a header in the source file

# %%
df1.columns=['id', 'surface']
df1.head(5)
# Out:
#    id  surface
# 0   0    28844
# 1   1    27667
# 2   2    14742
# 3   3    28089
# 4   4    11713

# %%
df2.columns=['id', 'bathrooms']
df2.head(5)
# Out:
#    id  bathrooms
# 0   0          2
# 1   1          1
# 2   2          1
# 3   3          3
# 4   4          1

# %%
df3.columns=['id', 'rooms']
df3.head(5)
# Out:
#    id  rooms
# 0   0      1
# 1   1      4
# 2   2      1
# 3   3      4
# 4   4      2

# %% [markdown]
#     4.Make an inner join of these four datasets into a single dataframe.

# %%
df = df1.merge(df2, on='id', how='inner').merge(df3,on='id', how='inner').merge(df4,on='id', how='inner')
df.head(10)
# Out:
#    id  surface  bathrooms  rooms  house_price
# 0   0    28844          2      1    1421908.0
# 1   1    27667          1      4    1305091.0
# 2   2    14742          1      1     164373.0
# 3   3    28089          3      4    1441714.0
# 4   4    11713          1      2     108290.0
# 5   5    28591          3      4    1703033.0
# 6   6    17385          3      3     340284.0
# 7   7    26197          2      3    1236645.0
# 8   8    17611          2      3     257405.0
# 9   9    12841          3      3     157433.0

# %% [markdown]
#     5.What is the average surface area of the houses in our dataset?

# %%
surfaceavg = df['surface'].mean()
print(round(surfaceavg,2))
# Out:
# 20439.77

# %% [markdown]
#     6.What is the median and average number of rooms?

# %%
roomedian = df['rooms'].median()
roomavg = round((df['rooms'].mean()),2)
print("The average number of room is {}, and the median number is {}.".format(roomavg,roomedian))
# Out:
# The average number of room is 2.42, and the median number is 2.0.

# %% [markdown]
#     7.What is the average cost of a house?

# %%
costavg = round((df['house_price'].mean()),2)
costavg
# Out:
# 767747.87

# %% [markdown]
#     8.What is the average cost of a house, depending on the number of rooms it has?

# %%
houseavg = round((df.groupby('rooms')['house_price'].mean()),2)
houseavg
# Out:
# rooms
# 1    980774.87
# 2    642086.26
# 3    645904.59
# 4    888045.63
# Name: house_price, dtype: float64

# %%
df.dtypes
# Out:
# id               int64
# surface          int64
# bathrooms        int64
# rooms            int64
# house_price    float64
# dtype: object

# %% [markdown]
#     9.The average cost per room doesn't tell us much. Let's try to categorize by size.
#     Create a new column in your dataset that we'll call home_size.
#
# Create three categories that respectively correspond to:
#
# "very large" == "a house larger than 25,000 sqrt_feet"
#
# "large" == "a house between 20,000 and 25,000 sqrt_feet"
#
# "medium" == "a house between 15,000 and 20,000 sqrt_feet"
#
# "small" == "a house between 10,000 and 15,000 sqrt_feet"
#
# "very small" == a house less than 10,000 sqrt_feet"
#
# Fill in the corresponding rows in the house_size column.

# %%
df['home_size'] = df['surface'] .apply(
    lambda x : "very large" if x > 25000 
    else "large" if (x > 20000 and x < 25000)
    else  "medium" if (x > 15000 and x < 20000)
    else  "small" if (x > 10000 and x < 15000) 
    else "very small")

pd.set_option('max_row', None)
df
# Out:
#     id  surface  bathrooms  rooms  house_price   home_size
# 0    0    28844          2      1    1421908.0  very large
# 1    1    27667          1      4    1305091.0  very large
# 2    2    14742          1      1     164373.0       small
# 3    3    28089          3      4    1441714.0  very large
# 4    4    11713          1      2     108290.0       small
# 5    5    28591          3      4    1703033.0  very large
# 6    6    17385          3      3     340284.0      medium
# 7    7    26197          2      3    1236645.0  very large
# 8    8    17611          2      3     257405.0      medium
# 9    9    12841          3      3     157433.0       small
# 10  10    25063          2      3    1697584.0  very large
# 11  11    20434          2      1     705365.0       large
# 12  12    29434          1      3    1702265.0  very large
# 13  13    12263          2      3     182191.0       small
# 14  14    26824          1      4    1918154.0  very large
# 15  15    12754          2      2     157223.0       small
# 16  16    21692          1      3     657944.0       large
# 17  17    27919          3      2    1823797.0  very large
# 18  18    17938          1      2     226206.0      medium
# 19  19    20928          3      2     974546.0       large
# 20  20    23496          2      2     679036.0       large
# 21  21    18413          2      4     269040.0      medium
# 22  22    10912          1      4     175919.0       small
# 23  23    12828          2      1     101448.0       small
# 24  24    29931          3      3    1926923.0  very large
# 25  25    13654          2      1     177995.0       small
# 26  26    15034          1      3     254477.0      medium
# 27  27    12570          3      2     172881.0       small
# 28  28    26102          3      1    1984103.0  very large
# 29  29    24685          1      3     671670.0       large
# 30  30    23872          2      4     739142.0       large
# 31  31    12347          1      3     138077.0       small
# 32  32    23845          1      1     802158.0       large
# 33  33    23378          2      2     999640.0       large
# 34  34    21413          1      4     815381.0       large
# 35  35    29792          2      4    1424754.0  very large
# 36  36    27443          3      2    1207939.0  very large
# 37  37    15816          2      2     409136.0      medium
# 38  38    27155          3      1    1124135.0  very large
# 39  39    26622          3      1    1307343.0  very large
# 40  40    20730          2      2     818882.0       large
# 41  41    26643          3      4    1395812.0  very large
# 42  42    13185          2      3     143573.0       small
# 43  43    10723          3      4     166583.0       small
# 44  44    16346          3      4     419235.0      medium
# 45  45    26343          1      3    1921487.0  very large
# 46  46    28108          1      1    1953216.0  very large
# 47  47    10799          1      3     184938.0       small
# 48  48    23595          3      3     562991.0       large
# 49  49    10916          3      3     137992.0       small
# 50  50    10502          3      2     146250.0       small
# 51  51    25648          2      4    1915963.0  very large
# 52  52    15105          2      2     449970.0      medium
# 53  53    21383          2      2     702677.0       large
# 54  54    27172          2      3    1186832.0  very large
# 55  55    14521          1      1     149843.0       small
# 56  56    29454          2      2    1330422.0  very large
# 57  57    11614          1      4     172084.0       small
# 58  58    15908          2      2     488708.0      medium
# 59  59    19671          2      2     367565.0      medium
# 60  60    28253          2      1    1100419.0  very large
# 61  61    26684          2      1    1968275.0  very large
# 62  62    19815          1      4     230820.0      medium
# 63  63    26048          2      2    1158550.0  very large
# 64  64    23185          2      1     614442.0       large
# 65  65    25847          1      2    1249756.0  very large
# 66  66    16604          1      4     437373.0      medium
# 67  67    20984          3      3     679388.0       large
# 68  68    24527          1      3     931942.0       large
# 69  69    29431          1      1    1146959.0  very large
# 70  70    26539          2      2    1621938.0  very large
# 71  71    19772          3      3     201553.0      medium
# 72  72    10198          3      4     171019.0       small
# 73  73    25890          3      1    1992653.0  very large
# 74  74    21734          3      2     854226.0       large
# 75  75    18818          3      1     201511.0      medium
# 76  76    16117          1      1     364103.0      medium
# 77  77    29449          1      2    1319862.0  very large
# 78  78    19946          2      4     333071.0      medium
# 79  79    19788          2      3     256222.0      medium
# 80  80    28233          2      1    1736070.0  very large
# 81  81    25647          3      1    1616313.0  very large
# 82  82    10560          3      2     190521.0       small
# 83  83    20143          3      3     561311.0       large
# 84  84    22915          2      3     572127.0       large
# 85  85    20389          1      1     857706.0       large
# 86  86    10915          1      3     139665.0       small
# 87  87    29924          1      4    1838679.0  very large
# 88  88    11671          1      2     182134.0       small
# 89  89    23736          1      1     550947.0       large
# 90  90    21132          1      1     516537.0       large
# 91  91    11408          2      2     163454.0       small
# 92  92    14471          3      2     103672.0       small
# 93  93    17744          2      2     444461.0      medium
# 94  94    20573          3      3     603906.0       large
# 95  95    11417          3      3     132599.0       small
# 96  96    12126          1      2     155828.0       small
# 97  97    16390          1      2     237061.0      medium
# 98  98    23738          1      2     976422.0       large
# 99  99    14613          2      2     183621.0       small

# %% [markdown]
#     10.What is the average cost of a house depending on its size category?

# %%
costsize = round((df.groupby('home_size')['house_price'].mean()),2)
costsize
# Out:
# home_size
# large          732538.52
# medium         325694.79
# small          156138.69
# very large    1552456.06
# Name: house_price, dtype: float64

# %% [markdown]
#     11.Apply the code below to view your result. What can you conclude?

# %%
sns.lmplot(x = "surface", y="house_price", data = df, aspect=18 / 8)
